# %%
#importing libraries required
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
file='Records Matching Task.xlsx'
data=pd.ExcelFile(file)

# %%
# reading the Data from the csv or given file format
data1 =data.parse('data1')


#Creating Unique column ID - "Data1_Unique_ID"
data1['Data1_Unique_ID'] = data1['Order ID']+data1['Product ID']
data1
# Out:
#             Order ID       Product ID  Qty                Data1_Unique_ID
# 0     CA-2014-100006  TEC-PH-10002075    3  CA-2014-100006TEC-PH-10002075
# 1     CA-2014-100090  FUR-TA-10003715    3  CA-2014-100090FUR-TA-10003715
# 2     CA-2014-100090  OFF-BI-10001597    6  CA-2014-100090OFF-BI-10001597
# 3     CA-2014-100293  OFF-PA-10000176    6  CA-2014-100293OFF-PA-10000176
# 4     CA-2014-100328  OFF-BI-10000343    1  CA-2014-100328OFF-BI-10000343
# ...              ...              ...  ...                            ...
# 9473  US-2017-169551  OFF-PA-10004100    3  US-2017-169551OFF-PA-10004100
# 9474  US-2017-169551  OFF-ST-10004835    3  US-2017-169551OFF-ST-10004835
# 9475  US-2017-169551  TEC-AC-10002018    3  US-2017-169551TEC-AC-10002018
# 9476  US-2017-169551  TEC-AC-10003033    2  US-2017-169551TEC-AC-10003033
# 9477  US-2017-169551  TEC-PH-10001363    2  US-2017-169551TEC-PH-10001363
#
# [9478 rows x 4 columns]

# %%
# reading the Data from the csv or given file format
data2 =data.parse('data2')

#Creating Unique column ID - "Data1_Unique_ID"
data2['Data2_Unique_ID'] = data2['Order ID']+data2['Product ID']

data2
# Out:
#             Order ID       Product ID  Qty                Data2_Unique_ID
# 0     CA-2014-100090  FUR-TA-10003715    3  CA-2014-100090FUR-TA-10003715
# 1     CA-2014-100090  OFF-BI-10001597    6  CA-2014-100090OFF-BI-10001597
# 2     CA-2014-100293  OFF-PA-10000176    6  CA-2014-100293OFF-PA-10000176
# 3     CA-2014-100328  OFF-BI-10000343    1  CA-2014-100328OFF-BI-10000343
# 4     CA-2014-100363  OFF-FA-10000611    2  CA-2014-100363OFF-FA-10000611
# ...              ...              ...  ...                            ...
# 9474  US-2017-169551  OFF-PA-10004100    3  US-2017-169551OFF-PA-10004100
# 9475  US-2017-169551  OFF-ST-10004835    3  US-2017-169551OFF-ST-10004835
# 9476  US-2017-169551  TEC-AC-10002018    3  US-2017-169551TEC-AC-10002018
# 9477  US-2017-169551  TEC-AC-10003033    2  US-2017-169551TEC-AC-10003033
# 9478  US-2017-169551  TEC-PH-10001363    2  US-2017-169551TEC-PH-10001363
#
# [9479 rows x 4 columns]

# %%
# Two data sets are merged on the common Unique ID
All_data = data1.merge(data2, how='outer', left_on=['Data1_Unique_ID'], right_on=['Data2_Unique_ID'])
All_data
# Out:
#           Order ID_x     Product ID_x  Qty_x                Data1_Unique_ID  \
# 0     CA-2014-100006  TEC-PH-10002075    3.0  CA-2014-100006TEC-PH-10002075
# 1     CA-2014-100090  FUR-TA-10003715    3.0  CA-2014-100090FUR-TA-10003715
# 2     CA-2014-100090  OFF-BI-10001597    6.0  CA-2014-100090OFF-BI-10001597
# 3     CA-2014-100293  OFF-PA-10000176    6.0  CA-2014-100293OFF-PA-10000176
# 4     CA-2014-100328  OFF-BI-10000343    1.0  CA-2014-100328OFF-BI-10000343
# ...              ...              ...    ...                            ...
# 9981             NaN              NaN    NaN                            NaN
# 9982             NaN              NaN    NaN                            NaN
# 9983             NaN              NaN    NaN                            NaN
# 9984             NaN              NaN    NaN                            NaN
# 9985             NaN              NaN    NaN                            NaN
#
# ...

# %% [markdown]
# # Question#1
# # How to identify the Records (Order ID + Product ID combination) present in data1
# # but missing in data2 (Specify the number of records missing in your answer)

# %%
Que1 = All_data[All_data['Data2_Unique_ID'].isna()]
Que1
# Out:
#           Order ID_x     Product ID_x  Qty_x                Data1_Unique_ID  \
# 0     CA-2014-100006  TEC-PH-10002075    3.0  CA-2014-100006TEC-PH-10002075
# 10    CA-2014-100678  OFF-EN-10000056    3.0  CA-2014-100678OFF-EN-10000056
# 19    CA-2014-100895  OFF-AR-10004511    2.0  CA-2014-100895OFF-AR-10004511
# 35    CA-2014-101560  OFF-BI-10000309    3.0  CA-2014-101560OFF-BI-10000309
# 61    CA-2014-102673  OFF-LA-10001771   12.0  CA-2014-102673OFF-LA-10001771
# ...              ...              ...    ...                            ...
# 9390  US-2017-160836  OFF-AP-10001626    2.0  US-2017-160836OFF-AP-10001626
# 9403  US-2017-162558  FUR-FU-10002364    2.0  US-2017-162558FUR-FU-10002364
# 9420  US-2017-163657  OFF-BI-10000138    5.0  US-2017-163657OFF-BI-10000138
# 9427  US-2017-164056  FUR-TA-10001307    5.0  US-2017-164056FUR-TA-10001307
# 9435  US-2017-165456  FUR-CH-10003981    6.0  US-2017-165456FUR-CH-10003981
#
#      Order ID_y Product ID_y  Qty_y Data2_Unique_ID
# ...

# %%
# number of samples " Present_in_Data1_missing_in_data2 "
Que1.shape[0]
# Out:
# 507

# %% [markdown]
# # Question#2
#
# # How to identify the Records (Order ID + Product ID combination) missing in data1 but present in data2 (Specify the number of records missing in your answer)

# %%
Que2 = Final_data[Final_data['Data1_Unique_ID'].isna()]
Que2
# Out:
#      Order ID_x Product ID_x  Qty_x Data1_Unique_ID      Order ID_y  \
# 9478        NaN          NaN    NaN             NaN  CA-2014-100706
# 9479        NaN          NaN    NaN             NaN  CA-2014-100762
# 9480        NaN          NaN    NaN             NaN  CA-2014-101427
# 9481        NaN          NaN    NaN             NaN  CA-2014-102652
# 9482        NaN          NaN    NaN             NaN  CA-2014-102869
# ...         ...          ...    ...             ...             ...
# 9981        NaN          NaN    NaN             NaN  US-2017-165344
# 9982        NaN          NaN    NaN             NaN  US-2017-165358
# 9983        NaN          NaN    NaN             NaN  US-2017-167920
# 9984        NaN          NaN    NaN             NaN  US-2017-169502
# 9985        NaN          NaN    NaN             NaN  US-2017-169551
#
#          Product ID_y  Qty_y                Data2_Unique_ID
# 9478  TEC-AC-10001314    2.0  CA-2014-100706TEC-AC-10001314
# ...

# %%
# number of samples " Present_in_Data2_missing_in_data1 "
Que2.shape[0]
# Out:
# 508

# %% [markdown]
# # Question#3
#
# # Find the Sum of the total Qty of Records missing in data1 but present in data2

# %%
# Sum of the total Qty of Records missing in data1 but present in data2
Que2['Qty_y'].sum()
# Out:
# 1956.0

# %% [markdown]
# # Question#4
#
# # Find the total number of unique records (Order ID + Product ID combination) present in the combined dataset of data1 and data2

# %%
# the total number of unique records (Order ID + Product ID combination) present in the combined dataset of data1 and data2
All_data.shape[0]
# Out:
# 9986

# %% [markdown]
# # Question#5
# # Common Between DATA1 and DATA2

# %%
# Find the total number of unique records (Order ID + Product ID combination) present in the combined dataset of data1 and data2 and "Present in BOTH"

# %%
Common_records = All_data[~((All_data['Data1_Unique_ID'].isna()) | (All_data['Data2_Unique_ID'].isna()))]

# %%
# Common_records_in_Data1_and_Data2
Common_records
# Out:
#           Order ID_x     Product ID_x  Qty_x                Data1_Unique_ID  \
# 1     CA-2014-100090  FUR-TA-10003715    3.0  CA-2014-100090FUR-TA-10003715
# 2     CA-2014-100090  OFF-BI-10001597    6.0  CA-2014-100090OFF-BI-10001597
# 3     CA-2014-100293  OFF-PA-10000176    6.0  CA-2014-100293OFF-PA-10000176
# 4     CA-2014-100328  OFF-BI-10000343    1.0  CA-2014-100328OFF-BI-10000343
# 5     CA-2014-100363  OFF-FA-10000611    2.0  CA-2014-100363OFF-FA-10000611
# ...              ...              ...    ...                            ...
# 9473  US-2017-169551  OFF-PA-10004100    3.0  US-2017-169551OFF-PA-10004100
# 9474  US-2017-169551  OFF-ST-10004835    3.0  US-2017-169551OFF-ST-10004835
# 9475  US-2017-169551  TEC-AC-10002018    3.0  US-2017-169551TEC-AC-10002018
# 9476  US-2017-169551  TEC-AC-10003033    2.0  US-2017-169551TEC-AC-10003033
# 9477  US-2017-169551  TEC-PH-10001363    2.0  US-2017-169551TEC-PH-10001363
#
# ...

# %%
# Number of " Common_records_in_Data1_and_Data2 "
Common_records.shape[0]
# Out:
# 8971
